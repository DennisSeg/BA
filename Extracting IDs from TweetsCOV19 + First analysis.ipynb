# %%
# Extract Tweet IDs from TweetsCOV19 into CSV
import csv,sys,json,carmen

#Path for TweetsCOV19
pathTweetsCOV19='C:/Users/dennis/Desktop/BachelorArbeit/TweetsCOV19.tsv'
#Path for new file with Tweet IDs
pathIDs='C:/Users/dennis/Desktop/tweetIDs.csv'


tweetIDs=[]
with open(pathTweetsCOV19, 'r', newline='',encoding="utf-8") as file:
    csv.field_size_limit(100000000)
    reader = csv.reader(file, delimiter='\t')
    for line in reader:
        tweetID=line[0]
        tweetIDs.append(tweetID)
        

with open (pathIDs, 'w', newline='',encoding="utf-8") as csvfile:   
        writer = csv.writer(csvfile, delimiter=';')
        for tweetID in tweetIDs:
            writer.writerow([tweetID])
            
# CSV file can be directly uploaded to application Hydrator

# %%
# Count of Tweets with features "Geo", "Place", "User Location"

import csv
import json

# Path to hydrated TweetsCOV19 file
fileHydrated = 'C:/Users/dennis/Desktop/Bachelorarbeit/HydratedALL.jsonl'

count_coordinates=0
count_location=0
count_place=0
count=0


with open(fileHydrated,encoding="utf8",errors='ignore') as hydratedJSON:
    for line in hydratedJSON:
        
        line=json.loads(line)
        print(line)
        break
        if line["coordinates"] is not None:            
            count_coordinates=count_coordinates+1
            
        if line["user"]["location"]:
            count_location=count_location+1
            
        if line["place"] is not None:
            count_place=count_place+1        
        count=count+1
print(count)        
print("Geo-coordinates: "+str(count_coordinates))
print("Place: "+str(count_location))
print("User location: "+str(count_place))
# Out:
# {'created_at': 'Tue Oct 01 00:30:17 +0000 2019', 'id': 1178829452240986000, 'id_str': '1178829452240986115', 'full_text': "My favourite home water filtration system is having a sale! These don't happen often, so check 'em out before it ends tonight, and save up to $250! https://t.co/9tbBeSOBOL\nYou can also read on my blog why I love Berkey Filters so much! #waterfiltration #healthyliving #cleanwater https://t.co/VWF8Xf7QC6", 'truncated': False, 'display_text_range': [0, 279], 'entities': {'hashtags': [{'text': 'waterfiltration', 'indices': [236, 252]}, {'text': 'healthyliving', 'indices': [253, 267]}, {'text': 'cleanwater', 'indices': [268, 279]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/9tbBeSOBOL', 'expanded_url': 'http://ow.ly/1q5050wxhzO', 'display_url': 'ow.ly/1q5050wxhzO', 'indices': [148, 171]}], 'media': [{'id': 1178829448390553600, 'id_str': '1178829448390553602', 'indices': [280, 303], 'media_url': 'http://pbs.twimg.com/media/EFwLIzoWsAI5Ftm.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EFwLIzoWsAI5Ftm.jpg', 'url': 'https://t.co/VWF8Xf7QC6', 'display_url': 'pic.twitter.com/VWF8Xf7QC6', 'expanded_url': 'https://twitter.com/hullosam/status/1178829452240986115/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 800, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1365, 'h': 2048, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1178829448390553600, 'id_str': '1178829448390553602', 'indices': [280, 303], 'media_url': 'http://pbs.twimg.com/media/EFwLIzoWsAI5Ftm.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EFwLIzoWsAI5Ftm.jpg', 'url': 'https://t.co/VWF8Xf7QC6', 'display_url': 'pic.twitter.com/VWF8Xf7QC6', 'expanded_url': 'https://twitter.com/hullosam/status/1178829452240986115/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 800, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1365, 'h': 2048, 'resize': 'fit'}}}]}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 21272482, 'id_str': '21272482', 'name': 'Sammie Kolk', 'screen_name': 'hullosam', 'location': 'Charlotte, NC', 'description': '🇨🇦👉🏼🇺🇸 📍: #CLT 💄: green beauty mua 💋: #makeuptipswithsammie 🧵: sustainable fashion 🌱: mindful living | health/wellness | gf+df 💌sammie@hullosam.com', 'url': 'https://t.co/qSrM7P57Bu', 'entities': {'url': {'urls': [{'url': 'https://t.co/qSrM7P57Bu', 'expanded_url': 'http://msha.ke/hullosam', 'display_url': 'msha.ke/hullosam', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1557, 'friends_count': 316, 'listed_count': 38, 'created_at': 'Thu Feb 19 03:35:42 +0000 2009', 'favourites_count': 4829, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 40718, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1101590781087891456/3VOx_k_s_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1101590781087891456/3VOx_k_s_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21272482/1551474669', 'profile_link_color': 'D4D04C', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '5E4F3D', 'profile_text_color': 'A86941', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile' ...
# 0
# Geo-coordinates: 0
# Place: 0
# User location: 0

# %%
# Plots to compare monthly tweets count between TweetsCOV19 and hydrated TweetsCOV19 dataset

import csv
import json
import pandas as pd

# Path to both dataset
tweetsCOV='C:/Users/Dennis/Desktop/BachelorArbeit/TweetsCOV19.tsv'
hydratedtweetsCOV='C:/Users/dennis/Desktop/BachelorArbeit/HydratedALL.jsonl'

df_tweetCOV = pd.read_csv(tweetsCOV, delimiter ='\t',names=['id','username',"timestamp","Follower","Friends","Retweets","Favorites","Entities","Sentiment","Mentions","Hashtags","URLs"])

hydratedTimestamps=[]
with open(hydratedtweetsCOV,encoding="utf8",errors='ignore') as hydratedJSON:
    for line in hydratedJSON:
        line=json.loads(line)
        hydratedTimestamps.append(line["created_at"])
        
# Create Timestamp dictionary for TweetsCOV19 dataset
import datetime
import matplotlib.pyplot as plot

df_timestamp=df_tweetCOV["timestamp"]

month_countTweetsCOV={}

for x in df_timestamp:
    time = datetime.datetime.strptime(x,'%a %b %d %H:%M:%S +%f %Y')
    month=time.strftime("%B")
    if month =="September":
        continue
    if month not in month_countTweetsCOV:
        month_countTweetsCOV[month]=1
    else:
        month_countTweetsCOV[month]=month_countTweetsCOV[month]+1

# Create Timestamp dictionary for Hydrated TweetsCOV19 dataset        
month_countHydrated={}

for timestamp in hydratedTimestamps:
    time = datetime.datetime.strptime(timestamp,'%a %b %d %H:%M:%S +%f %Y')
    month=time.strftime("%B")
    if month =="September":
        continue
    if month not in month_countHydrated:
        month_countHydrated[month]=1
    else:
        month_countHydrated[month]=month_countHydrated[month]+1
        
# Create Plots for both timestamp dictionaries        
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

listTweetCov=list(month_countTweetsCOV.values())
listHydrated=list(month_countHydrated.values())
listMonths=list(month_countTweetsCOV.keys())


x = np.arange(len(listMonths))  # the label locations

width = 0.3  # the width of the bars

fig, ax = plt.subplots()

ax.bar(x - width/2, listTweetCov, width, label='TweetsCOV19')
ax.bar(x + width/2, listHydrated, width, label='Hydrated')
#ax.set_ylabel('Count')
ax.set_title('Monthly Tweet Distribution')
ax.set_xticks(x)
ax.set_xticklabels(listMonths, fontsize=8)
ax.legend()

fig.tight_layout()

plt.show()

# %%
# Save plot to path
pathSave ='C:/Users/dennis/Desktop/monthlyDistribution.jpg'
fig.savefig(pathSave)
